# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("satislar.csv")
df.head()
# Out:
#    Aylar  Satislar
# 0      8   19671.5
# 1     10   23102.5
# 2     11   18865.5
# 3     13   21762.5
# 4     14   19945.5

# %%
plt.scatter(df["Aylar"],df["Satislar"])

# %%
from sklearn.linear_model import LinearRegression

lr  =LinearRegression()

# %%
x =df["Aylar"].values.reshape(-1,1)
y =df["Satislar"].values.reshape(-1,1)
print(x.shape)
print(y.shape)
# Out:
# (30, 1)
# (30, 1)

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.predict([[12],[10]])
# Out:
# array([[20289.96540812],
#        [18761.61216513]])
