# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("data.csv",sep=";",header=None)
x = df.iloc[:,0].values.reshape(-1,1)
y = df.iloc[:,1].values.reshape(-1,1)

# %%
rf = RandomForestRegressor(n_estimators=100,random_state=5) 
#100 => kaç tane Decission Tree kullanacaksın, 42 => n sayıda random bölme kod tekrar çalıştığında aynı sonucu verir
rf.fit(x,y)
# Out:
# C:\Users\yasar\AppData\Local\Temp\ipykernel_14016\4219303920.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x,y)
# RandomForestRegressor(random_state=5)

# %%
rf.predict(np.array(5.4).reshape(-1,1))
# Out:
# array([48.4])
